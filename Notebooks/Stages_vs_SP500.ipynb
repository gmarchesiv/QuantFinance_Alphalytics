# %%
# !pip install xlsxwriter
import pandas as pd
import numpy as np
from google.colab import files
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import statistics
import xlsxwriter
import random
import datetime
import time
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 149 kB 4.3 MB/s
# ...

# %%
file_name=files.upload()
name='SP_500_1985.csv'
# Out:
#      <input type="file" id="files-aafbad59-9f27-44b5-a453-18f324f5a16d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aafbad59-9f27-44b5-a453-18f324f5a16d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SP_500_1985.csv to SP_500_1985.csv

# %%
## Reading the file in 
df=pd.read_csv(name, sep=';')
rows=df.shape[0] #number of rows
columns=df.shape[1]  #number of columns
print(rows)
print (columns)
df.head()
# Out:
# 450
# 3
#     month   close       color
# 0  Ene-85  179.63  dark green
# 1  Feb-85  181.18  dark green
# 2  Mar-85  180.66  dark green
# 3  Abr-85  179.83  dark green
# 4  May-85  189.55  dark green

# %%
### Plotting From 1985 to 1991
fig, ax = plt.subplots(figsize=(15,10))
x = df['month'] [0:84]
y = df['close'] [0:84]
ax.plot(x, y, color='black')
w=ax.xaxis.set_major_locator(plt.MaxNLocator(9))
plt.xticks(w, rotation=45)
plt.xlabel('Month')
plt.ylabel('S&P 500')
plt.title('S&P 500 vs Economic Cycle Stage Jan 1985 - Dic 1991', size=14)
sns.despine()
 
for i in range(1,84,1):
  # print(i)
 
  if df['color'][i]  =="dark green":
    ax.axvspan(i-1, i, color='green', alpha=0.45, linewidth=0 )
  elif df['color'][i]  =="light green":
    ax.axvspan(i-1, i, color='green', alpha=0.15, linewidth=0 )
  elif df['color'][i]  =="red":
    ax.axvspan(i-1, i,   color='red', alpha=0.15, linewidth=0 )
  elif df['color'][i]  =="orange":
    ax.axvspan(i-1, i, color='orange', alpha=0.15, linewidth=0 )
  else:
    pass
plt.show()
plt.savefig("S&P 85-91.png");

# %%
### Plotting From 1992 to 2002 
fig, ax = plt.subplots(figsize=(15,10))
x = df['month'] [84:209]
y = df['close'] [84:209]
ax.plot(x, y, color='black')
w=ax.xaxis.set_major_locator(plt.MaxNLocator(9))
plt.xticks(w, rotation=45)
plt.xlabel('Month')
plt.ylabel('S&P 500')
plt.title('S&P 500 vs Economic Cycle Stage Jan 1992- May 2002', size=14)
sns.despine()
 
for i in range(1,125,1):
  # print(i,i+83)
  if df['color'][i+84]  =="dark green":
    ax.axvspan(i-1, i, color='green', alpha=0.45, linewidth=0 )
  elif df['color'][i+84]  =="light green":
    ax.axvspan(i-1, i, color='green', alpha=0.15, linewidth=0 )
  elif df['color'][i+84]  =="red":
    ax.axvspan(i-1, i,   color='red', alpha=0.15, linewidth=0 )
  elif df['color'][i+84]  =="orange":
    ax.axvspan(i-1, i, color='orange', alpha=0.15, linewidth=0 )
  else:
    pass
plt.savefig("S&P 92-02.png")
plt.show();

# %%
### Plotting From 2002 to 2010
fig, ax = plt.subplots(figsize=(15,10))
x = df['month'] [209:303]
y = df['close'] [209:303]
ax.plot(x, y, color='black')
w=ax.xaxis.set_major_locator(plt.MaxNLocator(9))
plt.xticks(w, rotation=45)
plt.xlabel('Month')
plt.ylabel('S&P 500')
plt.title('S&P 500 vs Economic Cycle Stage June 2002- April 2010', size=14)
sns.despine()
 
for i in range(1,94,1):
 
  if df['color'][i+209]  =="dark green":
    ax.axvspan(i-1, i, color='green', alpha=0.45, linewidth=0 )
  elif df['color'][i+209]  =="light green":
    ax.axvspan(i-1, i, color='green', alpha=0.15, linewidth=0 )
  elif df['color'][i+209]  =="red":
    ax.axvspan(i-1, i,   color='red', alpha=0.15, linewidth=0 )
  elif df['color'][i+209]  =="orange":
    ax.axvspan(i-1, i, color='orange', alpha=0.15, linewidth=0 )
  else:
    pass
plt.savefig("S&P 2002-2010.png")
plt.show();

# %%
### Plotting From 2010 to 2022
fig, ax = plt.subplots(figsize=(15,10))
x = df['month'] [303:450]
y = df['close'] [303:450]
ax.plot(x, y, color='black')
w=ax.xaxis.set_major_locator(plt.MaxNLocator(9))
plt.xticks(w, rotation=45)
plt.xlabel('Month')
plt.ylabel('S&P 500')
plt.title('S&P 500 vs Economic Cycle Stage April 2010- June 2022', size=14)
sns.despine()
 
for i in range(1,147,1):
 
  if df['color'][i+303]  =="dark green":
    ax.axvspan(i-1, i, color='green', alpha=0.45, linewidth=0 )
  elif df['color'][i+303]  =="light green":
    ax.axvspan(i-1, i, color='green', alpha=0.15, linewidth=0 )
  elif df['color'][i+303]  =="red":
    ax.axvspan(i-1, i,   color='red', alpha=0.15, linewidth=0 )
  elif df['color'][i+303]  =="orange":
    ax.axvspan(i-1, i, color='orange', alpha=0.15, linewidth=0 )
  else:
    pass
plt.savefig("S&P 2010-2022.png")
plt.show();
